# %%
# %matplotlib inline 

import pandas as pd
import numpy as np 

import seaborn as sns 
import matplotlib.pyplot as plt

# %config InlineBackend.figure_format = 'retina'
sns.set()
#^ to make the chart rendered to be nicer.

# DataFrame, special object to load data into a table (like Excel)
df = pd.read_csv("https://raw.githubusercontent.com/theleadio/datascience_demo/master/HR_dataset.csv")

df.sample(50)
# Out:
#                     names  satisfaction_level  last_evaluation  \
# 1531      Ramon Hilsinger                0.36             0.57
# 4142         Leslie Jones                0.60             0.53
# 11487        Jack Rowland                0.75             0.53
# 6731       Jeffrey Starks                0.55             0.46
# 3809   Harriette Shaffner                0.49             0.48
# 14998    Randall Williams                0.37             0.52
# 1511     Brittany Modesto                0.40             0.46
# 11215         Maggie Giel                0.52             0.84
# 2523      Dora Fredericks                0.90             0.87
# 11168          Maria Dodd                0.17             0.36
# 13383       Reiko Goodwin                0.67             0.52
# 5067          Mindy Polly                0.89             0.62
# 10723    Daniel Steinmetz                0.60             0.80
# 12093       Allen Maxwell                0.46             0.55
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   names                  15000 non-null  object
#  1   satisfaction_level     15000 non-null  float64
#  2   last_evaluation        15000 non-null  float64
#  3   number_project         15000 non-null  int64
#  4   average_monthly_hours  15000 non-null  int64
#  5   exp_in_company         15000 non-null  int64
#  6   work_accident          15000 non-null  int64
#  7   left                   15000 non-null  int64
#  8   promotion_last_5years  15000 non-null  int64
#  9   role                   15000 non-null  object
#  10  salary                 15000 non-null  object
# dtypes: float64(2), int64(6), object(3)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        15000.000000     15000.000000    15000.000000
# mean             0.612847         0.716115        3.803133
# std              0.248628         0.171171        1.232590
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_monthly_hours  exp_in_company  work_accident          left  \
# count           15000.000000    15000.000000   15000.000000  15000.000000
# mean              201.052400        3.498333       0.144600      0.238133
# std                49.942074        1.460139       0.351709      0.425955
# min                96.000000        2.000000       0.000000      0.000000
# ...

# %%
# findings..

# count in the first row help us idenity the completeness of the data. each are 15K is saying that data is complete. 

# mean > in the table we identify that poeple averagely work for 3.5 years in the Company. 14% work accident rate. 

# satisfaction level: 50% - half of the population are in statiscation level of 64% which the mean of the total satisfaciton level is 61%
# last_evaluation score: the total population scored 71.6% in average during the evaluation. 3/4 of the population scored 87% in the evaluation scored.

# %%
sns.set(rc={'figure.figsize':(12,10)})
sns.set_context("talk", font_scale=1)
#sns = seaborn    
#corr = correlation
#annot = annotation
sns.heatmap(df.corr(), cmap='Reds', annot=True)

# %%
## In the heat map, the correlation represented as positive (higher , higher) or negative (higher, lower) only determine as direction.

# %%
ax = sns.countplot(df['role'])

loc, labels = plt.xticks()
ax.set_xticklabels(labels, rotation=90);

# %%
# other type of charts can refer to seaborn documentation: https://seaborn.pydata.org/

# %%
sns.countplot(x="salary", hue="role", data=df, palette='Set2')

#Hue : colour

# %%
sns.countplot(x="number_project", hue="left", data=df)

# %%
sns.distplot(df['satisfaction_level'], norm_hist=False, kde=False)

# %%
sns.distplot(df['average_monthly_hours'], norm_hist=False, kde=False)

# %%
# from sklearn.model_selection import train_test_split

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
#sklearn -> scikit-learn
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

columns = ['satisfaction_level','number_project']

# Establishing the base dataset
X = df[columns]
y = df['left'] 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

## model >>> y = Mx + C  

from sklearn.metrics import accuracy_score
##sklaern help us to calculate the accuracy of the data

logmodel = LogisticRegression()

#^ fit in training data X & training data y
logmodel.fit(X_train,y_train)

predictions = logmodel.predict(X_test)

accuracy_score(y_test,predictions)
# Out:
# 0.7686868686868686

# %%
print(predictions)
# Out:
# [0 0 0 ... 0 0 1]

# %%
predict = pd.read_csv("https://raw.githubusercontent.com/theleadio/datascience_demo/master/hr_predict.csv")

X_predict = predict[columns]
predictions = logmodel.predict(X_predict)
predict['left_predict'] = predictions

predict
# Out:
#        id           names  satisfaction_level  last_evaluation  \
# 0    2237     Paul Mathey                0.74             0.72
# 1    8127    Shawn Torres                0.72             0.88
# 2    8146   Emily Staples                0.52             0.67
# 3   14441    Jean Salazar                0.42             0.47
# 4   11909    Javier Folse                0.85             0.58
# ..    ...             ...                 ...              ...
# 95  12162    Robert Davis                0.45             0.51
# 96  14646      Kevin Reid                0.41             0.47
# 97  10385     Mary Valdez                0.99             0.50
# 98   9524  William Jaeger                0.74             0.55
# 99  13936     John Booker                0.16             0.63
#
#     number_project  average_monthly_hours  exp_in_company  work_accident  \
# 0                4                    176               3              0
# ...

# %%
## Over fitting model = "when your model is too perfect but does not fit into the real world."

# %%
predict 

df.to_excel(r'C:\Users\HP\Downloads\3. Data science Jupyter Notebook\Data Science 360 pracitces\Potential_Leavers.xlsx', index = False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     315             try:
# --> 316                 self._store_workbook()
#     317             except IOError as e:
#
# ~\anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     631         except IOError as e:
# --> 632             raise e
#     633
#
# ~\anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     629             xlsx_file = ZipFile(self.filename, "w", compression=ZIP_DEFLATED,
# --> 630                                 allowZip64=self.allow_zip64)
#     631         except IOError as e:
#
# ~\anaconda3\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel)
#    1239                 try:
# -> 1240                     self.fp = io.open(file, filemode)
# ...
